# %%
import pandas as pd

df = pd.read_excel('fr-en-annuaire-education.xlsx', engine='openpyxl')

# %%
df
# Out:
#       Identifiant_de_l_etablissement  \
# 0                           0631348Y
# 1                           0631425G
# 2                           0631433R
# 3                           0631441Z
# 4                           0631485X
# ...                              ...
# 68931                       0730063X
# 68932                       0731102B
# 68933                       0731449D
# 68934                       0740076F
# 68935                       0740079J
#
#                                        Nom_etablissement  \
# 0        Ecole élémentaire privée Pensionnat Sainte Anne
# 1                             Ecole primaire la Dordogne
# 2         Ecole maternelle d'application Aristide Briand
# 3                                 Ecole primaire Turelet
# 4                           Ecole maternelle Jules Verne
# ...                                                  ...
# 68931  Circonscription d'inspection du 1er degré de M...
# ...

# %%
df.shape
# Out:
# (68936, 71)

# %%
ds.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ds.columns
#
# NameError: name 'ds' is not defined

# %%
df.columns
# Out:
# Index(['Identifiant_de_l_etablissement', 'Nom_etablissement',
#        'Type_etablissement', 'Statut_public_prive', 'Adresse_1', 'Adresse_2',
#        'Adresse_3', 'Code_postal', 'Code_commune', 'Nom_commune',
#        'Code_departement', 'Code_academie', 'Code_region', 'Ecole_maternelle',
#        'Ecole_elementaire', 'Voie_generale', 'Voie_technologique',
#        'Voie_professionnelle', 'Telephone', 'Fax', 'Web', 'Mail',
#        'Restauration', 'Hebergement', 'ULIS', 'Apprentissage', 'Segpa',
#        'Section_arts', 'Section_cinema', 'Section_theatre', 'Section_sport',
#        'Section_internationale', 'Section_europeenne', 'Lycee_Agricole',
#        'Lycee_militaire', 'Lycee_des_metiers', 'Post_BAC',
#        'Appartenance_Education_Prioritaire', 'GRETA', 'SIREN_SIRET',
#        'Fiche_onisep', 'position', 'Type_contrat_prive', 'Libelle_departement',
#        'Libelle_academie', 'Libelle_region', 'coordX_origine',
# ...

# %%
import pandas as pd

# Charger le fichier Excel
df = pd.read_excel('fr-en-annuaire-education.xlsx', engine='openpyxl')

# Colonnes utiles
colonnes_utiles = [
    'Nom_etablissement',
    'Type_etablissement',
    'Statut_public_prive',
    'Web',
    'Telephone',
    'Mail',
    'Code_postal',
    'Nom_commune',
    'Libelle_departement',
    'Libelle_academie'
]

df = df[colonnes_utiles]
df.head()
# Out:
#                                  Nom_etablissement Type_etablissement  \
# 0  Ecole élémentaire privée Pensionnat Sainte Anne              Ecole
# 1                       Ecole primaire la Dordogne              Ecole
# 2   Ecole maternelle d'application Aristide Briand              Ecole
# 3                           Ecole primaire Turelet              Ecole
# 4                     Ecole maternelle Jules Verne              Ecole
#
#   Statut_public_prive  Web   Telephone                        Mail  \
# 0               Privé  NaN  0473621046  ce.0631348Y@ac-clermont.fr
# 1              Public  NaN  0473810425  ce.0631425G@ac-clermont.fr
# 2              Public  NaN  0473935287  ce.0631433R@ac-clermont.fr
# 3              Public  NaN  0473802379  ce.0631441Z@ac-clermont.fr
# 4              Public  NaN  0473408822  ce.0631485X@ac-clermont.fr
#
#    Code_postal       Nom_commune Libelle_departement  Libelle_academie
# ...
